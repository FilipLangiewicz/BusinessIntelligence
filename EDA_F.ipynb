# %% [markdown]
# # EDA

# %%
import pandas as pd

# %%
data = pd.read_csv('./airbnb_data/20241206_france_ile-de-france_paris_listings.csv')

# %%
data['bathrooms']
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        NaN
# 4        1.0
#         ...
# 91026    1.0
# 91027    1.0
# 91028    3.5
# 91029    3.0
# 91030    1.0
# Name: bathrooms, Length: 91031, dtype: float64

# %%
# check number of columns
import os

for file in os.listdir('./airbnb_data/'):
    if file.endswith('listings.csv'):
        data = pd.read_csv(f'./airbnb_data/{file}')
        print(f"Number of columns: {len(data.columns)}. File: {file}")
# Out:
# Number of columns: 46. File: 20241227_chile_rm_santiago_listings.csv
# Number of columns: 46. File: 20241227_china_beijing_beijing_listings.csv
# Number of columns: 46. File: 20250129_argentina_ciudad-autónoma-de-buenos-aires_buenos-aires_listings.csv
# Number of columns: 46. File: 20250301_united-states_ca_los-angeles_listings.csv
# Number of columns: 46. File: 20250301_united-states_ca_san-francisco_listings.csv
# Number of columns: 46. File: 20250302_australia_tas_tasmania_listings.csv
# Number of columns: 46. File: 20250302_italy_veneto_venice_listings.csv
# Number of columns: 46. File: 20250302_the-netherlands_north-holland_amsterdam_listings.csv
# Number of columns: 46. File: 20250302_united-states_la_new-orleans_listings.csv
# Number of columns: 46. File: 20250303_australia_nsw_sydney_listings.csv
# Number of columns: 46. File: 20250303_australia_vic_melbourne_listings.csv
# Number of columns: 46. File: 20250303_france_ile-de-france_paris_listings.csv
# ...
